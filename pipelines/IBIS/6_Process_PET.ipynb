# %% [markdown]
# **Sets directories:**
#    - **anapyze_dir:** Directory where the anapyze_directory is located
#    - **dir_patients:** The directory resulting from 0_Reorder_Data or 0_Reorder_ADNI

# %%
import warnings

warnings.filterwarnings("ignore")

import os, sys
import nibabel as nib
from nibabel import processing as nibproc
from os.path import join, exists, isdir
import numpy as np

anapyze_dir = r'/Users/jsilva/repositories/anapyze'
anapyze_rsc = join(anapyze_dir, 'resources')
sys.path.insert(0, anapyze_dir)

from spm import SPM

dir_patients = r'/Volumes/txusser_data/IBIS_DATA/Reorder_New/'

# %% [markdown]
# **Sets directories:**
#
#    - **template_pet:** Different templates are available at anapyze/resource/templates/ or you can bring your own
#    - **run_spm_file_in_Python:** If you have configured the paths from spm in spm_proc, you can set this to true. Othwerwise you must run the created normalize.m in MATLAB with SPM

# %%
# Put your data directory here
# Change your templates here if necessary
template_pet = join(anapyze_rsc, 'templates', 'FDG_PET_template.nii')

spm_proc = SPM(r'/Users/jsilva', r'/Users/jsilva')
run_spm_file_in_Python = False

if template_pet[-2:] == 'gz':
    img_ = nib.load(template_pet)
    data_ = img_.get_fdata()
    out = nib.Nifti1Image(data_, img_.affine, img_.header)
    nib.save(out, template_pet[0:-3])
    print(f"Decompressed: {template_pet}. SPM does not accept .nii.gz files...")
    template_pet = template_pet[0:-3]

list_dirs = os.listdir(dir_patients)

#This will create a cat_12.m file that must be run on MATLAB separately

images = []

for i in list_dirs:
    
    dir_subj = join(dir_patients, i)
    
    if isdir(dir_subj):

        print('\nProcessing %s: Subject %s/%s' % (i, list_dirs.index(i), len(list_dirs)))
    
        list_subj = os.listdir(dir_subj)
    
        fdg_list = []
    
        for j in list_subj:
            if j.startswith('fdg_'):
                fdg_list.append(j)
    
        for k in fdg_list:
            
            pet_dir = join(dir_patients, i, k)
            
            check_cat_processing = [join(pet_dir, 'wpet.img')]
        
            if all(exists(j) for j in check_cat_processing):
                pass
        
            else:
        
                pet_in = join(pet_dir, 'pet.img')
        
                if exists(pet_in):
                    images.append(pet_in)
    
dir_proc = os.getcwd()
    
norm_spm = spm_proc.normalize_multiple_pets(dir_proc, images, template_pet, cutoff=15, nits=16, reg=1,
                                                preserve=0, affine_regularization_type='mni', source_image_smoothing=8,
                                                template_image_smoothing=3, bb=None,
                                                write_vox_size='[1.5 1.5 1.5]', wrapping=True, interpolation=4, prefix='w',
                                                run=run_spm_file_in_Python)
# Out:
# Processing 11409: Subject 0/310
#
# Processing 1080: Subject 1/310
#
# Processing 11443: Subject 2/310
#
# Processing 11446: Subject 3/310
#
# Processing 11453: Subject 4/310
#
# Processing 11460: Subject 5/310
#
# Processing 11477: Subject 6/310
#
# Processing 11495: Subject 7/310
#
# Processing 11614: Subject 8/310
#
# Processing 11627: Subject 9/310
#
# Processing 11731: Subject 10/310
#
# Processing 11732: Subject 11/310
#
# Processing 11766: Subject 12/310
#
# Processing 11778: Subject 13/310
#
# Processing 11782: Subject 14/310
#
# Processing 11797: Subject 15/310
#
# Processing 11841: Subject 16/310
#
# Processing 11862: Subject 17/310
#
# Processing 11879: Subject 18/310
#
# Processing 11904: Subject 19/310
#
# Processing 11913: Subject 20/310
#
# Processing 11950: Subject 21/310
#
# Processing 11962: Subject 22/310
#
# Processing 11974: Subject 23/310
#
# Processing 12011: Subject 24/310
#
# Processing 13033: Subject 25/310
#
# Processing 13043: Subject 26/310
#
# Processing 13050: Subject 27/310
#
# Processing 13059: Subject 28/310
#
# Processing 13067: Subject 29/310
#
# Processing 1307: Subject 30/310
#
# Processing 13076: Subject 31/310
#
# Processing 13091: Subject 32/310
#
# Processing 1389: Subject 33/310
#
# Processing 14091: Subject 34/310
#
# Processing 14093: Subject 35/310
#
# Processing 14120: Subject 36/310
#
# Processing 14121: Subject 37/310
#
# Processing 14122: Subject 38/310
#
# Processing 14123: Subject 39/310
#
# Processing 1436: Subject 40/310
#
# Processing 1494: Subject 41/310
#
# Processing 15156: Subject 42/310
#
# Processing 15159: Subject 43/310
#
# Processing 15184: Subject 44/310
#
# Processing 15219: Subject 45/310
#
# Processing 15220: Subject 46/310
#
# Processing 15258: Subject 47/310
#
# Processing 15260: Subject 48/310
#
# Processing 15266: Subject 49/310
#
# Processing 15272: Subject 50/310
#
# Processing 15274: Subject 51/310
#
# Processing 15276: Subject 52/310
#
# Processing 15300: Subject 53/310
#
# Processing 15332: Subject 54/310
#
# Processing 15420: Subject 55/310
#
# Processing 15441: Subject 56/310
#
# Processing 15442: Subject 57/310
#
# Processing 15446: Subject 58/310
#
# Processing 15457: Subject 59/310
#
# Processing 15541: Subject 60/310
#
# Processing 15553: Subject 61/310
#
# Processing 15554: Subject 62/310
#
# Processing 15555: Subject 63/310
#
# Processing 15557: Subject 64/310
#
# Processing 15583: Subject 65/310
#
# Processing 15592: Subject 66/310
#
# Processing 15593: Subject 67/310
#
# Processing 15600: Subject 68/310
#
# Processing 15607: Subject 69/310
#
# Processing 15609: Subject 70/310
#
# Processing 15621: Subject 71/310
#
# Processing 15635: Subject 72/310
#
# Processing 15636: Subject 73/310
#
# Processing 15639: Subject 74/310
#
# Processing 15659: Subject 75/310
#
# Processing 15683: Subject 76/310
#
# Processing 15694: Subject 77/310
#
# Processing 15696: Subject 78/310
#
# Processing 15709: Subject 79/310
#
# Processing 15710: Subject 80/310
#
# Processing 15713: Subject 81/310
#
# Processing 15714: Subject 82/310
#
# Processing 15724: Subject 83/310
#
# Processing 15731: Subject 84/310
#
# Processing 15741: Subject 85/310
#
# Processing 15783: Subject 86/310
#
# Processing 15784: Subject 87/310
#
# Processing 15791: Subject 88/310
#
# Processing 15792: Subject 89/310
#
# Processing 15797: Subject 90/310
#
# Processing 15798: Subject 91/310
#
# Processing 15800: Subject 92/310
#
# Processing 15801: Subject 93/310
#
# Processing 15804: Subject 94/310
#
# Processing 15805: Subject 95/310
#
# Processing 15809: Subject 96/310
#
# Processing 15849: Subject 97/310
#
# Processing 15850: Subject 98/310
#
# Processing 15855: Subject 99/310
#
# Processing 15856: Subject 100/310
#
# Processing 15861: Subject 101/310
#
# Processing 15869: Subject 102/310
#
# Processing 15914: Subject 103/310
#
# Processing 15958: Subject 104/310
#
# Processing 15966: Subject 105/310
#
# Processing 16018: Subject 106/310
#
# Processing 16072: Subject 107/310
#
# Processing 16084: Subject 108/310
#
# Processing 16088: Subject 109/310
#
# Processing 16098: Subject 110/310
#
# Processing 16109: Subject 111/310
#
# Processing 16131: Subject 112/310
#
# Processing 16146: Subject 113/310
#
# Processing 16149: Subject 114/310
#
# Processing 16160: Subject 115/310
#
# Processing 16161: Subject 116/310
#
# Processing 16206: Subject 117/310
#
# Processing 16219: Subject 118/310
#
# Processing 16227: Subject 119/310
#
# Processing 16233: Subject 120/310
#
# Processing 16236: Subject 121/310
#
# Processing 16272: Subject 122/310
#
# Processing 16276: Subject 123/310
#
# Processing 16278: Subject 124/310
#
# Processing 16312: Subject 125/310
#
# Processing 16318: Subject 126/310
#
# Processing 16320: Subject 127/310
#
# Processing 16323: Subject 128/310
#
# Processing 16324: Subject 129/310
#
# Processing 16325: Subject 130/310
#
# Processing 16326: Subject 131/310
#
# Processing 16337: Subject 132/310
#
# Processing 16339: Subject 133/310
#
# Processing 16342: Subject 134/310
#
# Processing 16343: Subject 135/310
#
# Processing 16349: Subject 136/310
#
# Processing 16350: Subject 137/310
#
# Processing 16356: Subject 138/310
#
# Processing 16360: Subject 139/310
#
# Processing 16364: Subject 140/310
#
# Processing 16365: Subject 141/310
#
# Processing 16366: Subject 142/310
#
# Processing 16367: Subject 143/310
#
# Processing 16368: Subject 144/310
#
# Processing 16369: Subject 145/310
#
# Processing 16388: Subject 146/310
#
# Processing 16391: Subject 147/310
#
# Processing 16392: Subject 148/310
#
# Processing 16393: Subject 149/310
#
# Processing 16394: Subject 150/310
#
# Processing 16395: Subject 151/310
#
# Processing 16396: Subject 152/310
#
# Processing 16397: Subject 153/310
#
# Processing 16398: Subject 154/310
#
# Processing 16399: Subject 155/310
#
# Processing 16409: Subject 156/310
#
# Processing 16410: Subject 157/310
#
# Processing 16414: Subject 158/310
#
# Processing 16428: Subject 159/310
#
# Processing 16429: Subject 160/310
#
# Processing 16446: Subject 161/310
#
# Processing 16453: Subject 162/310
#
# Processing 16513: Subject 163/310
#
# Processing 16514: Subject 164/310
#
# Processing 16522: Subject 165/310
#
# Processing 16534: Subject 166/310
#
# Processing 16536: Subject 167/310
#
# Processing 16537: Subject 168/310
#
# Processing 16545: Subject 169/310
#
# Processing 16547: Subject 170/310
#
# Processing 16548: Subject 171/310
#
# Processing 16549: Subject 172/310
#
# Processing 16551: Subject 173/310
#
# Processing 16552: Subject 174/310
#
# Processing 16572: Subject 175/310
#
# Processing 16573: Subject 176/310
#
# Processing 16575: Subject 177/310
#
# Processing 16578: Subject 178/310
#
# Processing 16587: Subject 179/310
#
# Processing 16600: Subject 180/310
#
# Processing 16617: Subject 181/310
#
# Processing 16636: Subject 182/310
#
# Processing 16637: Subject 183/310
#
# Processing 16638: Subject 184/310
#
# Processing 16639: Subject 185/310
#
# Processing 16654: Subject 186/310
#
# Processing 16655: Subject 187/310
#
# Processing 16658: Subject 188/310
#
# Processing 16662: Subject 189/310
#
# Processing 16666: Subject 190/310
#
# Processing 16667: Subject 191/310
#
# Processing 16681: Subject 192/310
#
# Processing 16686: Subject 193/310
#
# Processing 16689: Subject 194/310
#
# Processing 16690: Subject 195/310
#
# Processing 16691: Subject 196/310
#
# Processing 16716: Subject 197/310
#
# Processing 16722: Subject 198/310
#
# Processing 16724: Subject 199/310
#
# Processing 16727: Subject 200/310
#
# Processing 16728: Subject 201/310
#
# Processing 16732: Subject 202/310
#
# Processing 16737: Subject 203/310
#
# Processing 16745: Subject 204/310
#
# Processing 16750: Subject 205/310
#
# Processing 16761: Subject 206/310
#
# Processing 16790: Subject 207/310
#
# Processing 16841: Subject 208/310
#
# Processing 16842: Subject 209/310
#
# Processing 16869: Subject 210/310
#
# Processing 16874: Subject 211/310
#
# Processing 16878: Subject 212/310
#
# Processing 16881: Subject 213/310
#
# Processing 16908: Subject 214/310
#
# Processing 16915: Subject 215/310
#
# Processing 16935: Subject 216/310
#
# Processing 17063: Subject 217/310
#
# Processing 17193: Subject 218/310
#
# Processing 17267: Subject 219/310
#
# Processing 1761: Subject 220/310
#
# Processing 1765: Subject 221/310
#
# Processing 2858: Subject 222/310
#
# Processing 2874: Subject 223/310
#
# Processing 2944: Subject 224/310
#
# Processing 3057: Subject 225/310
#
# Processing 3069: Subject 226/310
#
# Processing 3116: Subject 227/310
#
# Processing 3319: Subject 228/310
#
# Processing 3464: Subject 229/310
#
# Processing 3535: Subject 230/310
#
# Processing 3536: Subject 231/310
#
# Processing 3974: Subject 232/310
#
# Processing 3978: Subject 233/310
#
# Processing 4122: Subject 234/310
#
# Processing 4214: Subject 235/310
#
# Processing 4230: Subject 236/310
#
# Processing 4252: Subject 237/310
#
# Processing 4334: Subject 238/310
#
# Processing 4355: Subject 239/310
#
# Processing 4358: Subject 240/310
#
# Processing 4364: Subject 241/310
#
# Processing 4429: Subject 242/310
#
# Processing 4442: Subject 243/310
#
# Processing 4507: Subject 244/310
#
# Processing 4576: Subject 245/310
#
# Processing 4734: Subject 246/310
#
# Processing 4779: Subject 247/310
#
# Processing 5209: Subject 248/310
#
# Processing 5212: Subject 249/310
#
# Processing 5328: Subject 250/310
#
# Processing 5363: Subject 251/310
#
# Processing 5457: Subject 252/310
#
# Processing 5660: Subject 253/310
#
# Processing 5690: Subject 254/310
#
# Processing 5736: Subject 255/310
#
# Processing 5746: Subject 256/310
#
# Processing 5767: Subject 257/310
#
# Processing 5817: Subject 258/310
#
# Processing 5982: Subject 259/310
#
# Processing 6016: Subject 260/310
#
# Processing 6034: Subject 261/310
#
# Processing 6081: Subject 262/310
#
# Processing 6111: Subject 263/310
#
# Processing 6116: Subject 264/310
#
# Processing 6147: Subject 265/310
#
# Processing 6148: Subject 266/310
#
# Processing 6183: Subject 267/310
#
# Processing 6193: Subject 268/310
#
# Processing 6221: Subject 269/310
#
# Processing 6226: Subject 270/310
#
# Processing 6228: Subject 271/310
#
# Processing 6257: Subject 272/310
#
# Processing 6323: Subject 273/310
#
# Processing 6340: Subject 274/310
#
# Processing 6343: Subject 275/310
#
# Processing 6344: Subject 276/310
#
# Processing 6399: Subject 277/310
#
# Processing 6400: Subject 278/310
#
# Processing 6401: Subject 279/310
#
# Processing 6402: Subject 280/310
#
# Processing 6403: Subject 281/310
#
# Processing 6404: Subject 282/310
#
# Processing 6406: Subject 283/310
#
# Processing 6545: Subject 284/310
#
# Processing 6818: Subject 285/310
#
# Processing 6830: Subject 286/310
#
# Processing 6874: Subject 287/310
#
# Processing 6895: Subject 288/310
#
# Processing 6903: Subject 289/310
#
# Processing 6904: Subject 290/310
#
# Processing 6905: Subject 291/310
#
# Processing 6906: Subject 292/310
#
# Processing 6914: Subject 293/310
#
# Processing 6968: Subject 294/310
#
# Processing 7011: Subject 295/310
#
# Processing 784: Subject 296/310
#
# Processing 8037: Subject 297/310
#
# Processing 8061: Subject 298/310
#
# Processing 8079: Subject 299/310
#
# Processing 8083: Subject 300/310
#
# Processing 9009: Subject 301/310
#
# Processing 9037: Subject 302/310
#
# Processing 9069: Subject 303/310
#
# Processing 9071: Subject 304/310
#
# Processing 9114: Subject 305/310
#
# Processing 9314: Subject 306/310
#
# Processing 983: Subject 307/310
#
# Processing 15810: Subject 308/310

# %%
for i in list_dirs:

    dir_subj = join(dir_patients, i)

    if isdir(dir_subj):

        print('\nProcessing %s: Subject %s/%s' % (i, list_dirs.index(i), len(list_dirs)))

        list_subj = os.listdir(dir_subj)

        fdg_list = []

        for j in list_subj:
            if j.startswith('fdg_'):
                fdg_list.append(j)

        for k in fdg_list:
            
            pet_in = join(dir_subj, k, 'wpet.hdr')
            
            if exists(pet_in):
                siemens_file = join(dir_subj, k, '1080')
                if exists(siemens_file):
                    smoothing = 2.5
                else:
                    smoothing = 6.5

                img_ = nib.load(pet_in)
                smoothed_pons = nibproc.smooth_image(img_, smoothing, out_class=nib.Nifti1Image)
                data_ = smoothed_pons.get_fdata()

                smoothed_output = join(dir_subj, k, 'swpet.hdr')
                out_img = nib.Nifti1Image(data_, img_.affine, img_.header)
                nib.save(out_img, smoothed_output)
            else:
                print('wpet MISSING!!!!')
# Out:
# Processing 11409: Subject 0/310
#
# Processing 1080: Subject 1/310
#
# Processing 11443: Subject 2/310
#
# Processing 11446: Subject 3/310
#
# Processing 11453: Subject 4/310
#
# Processing 11460: Subject 5/310
#
# Processing 11477: Subject 6/310
#
# Processing 11495: Subject 7/310
#
# Processing 11614: Subject 8/310
#
# Processing 11627: Subject 9/310
#
# Processing 11731: Subject 10/310
#
# Processing 11732: Subject 11/310
#
# Processing 11766: Subject 12/310
#
# Processing 11778: Subject 13/310
#
# Processing 11782: Subject 14/310
#
# Processing 11797: Subject 15/310
#
# Processing 11841: Subject 16/310
#
# Processing 11862: Subject 17/310
#
# Processing 11879: Subject 18/310
#
# Processing 11904: Subject 19/310
#
# Processing 11913: Subject 20/310
#
# Processing 11950: Subject 21/310
#
# Processing 11962: Subject 22/310
#
# Processing 11974: Subject 23/310
#
# Processing 12011: Subject 24/310
#
# Processing 13033: Subject 25/310
#
# Processing 13043: Subject 26/310
#
# Processing 13050: Subject 27/310
#
# Processing 13059: Subject 28/310
#
# Processing 13067: Subject 29/310
#
# Processing 1307: Subject 30/310
#
# Processing 13076: Subject 31/310
#
# Processing 13091: Subject 32/310
#
# Processing 1389: Subject 33/310
#
# Processing 14091: Subject 34/310
#
# Processing 14093: Subject 35/310
#
# Processing 14120: Subject 36/310
#
# Processing 14121: Subject 37/310
#
# Processing 14122: Subject 38/310
#
# Processing 14123: Subject 39/310
#
# Processing 1436: Subject 40/310
#
# Processing 1494: Subject 41/310
#
# Processing 15156: Subject 42/310
#
# Processing 15159: Subject 43/310
#
# Processing 15184: Subject 44/310
#
# Processing 15219: Subject 45/310
#
# Processing 15220: Subject 46/310
#
# Processing 15258: Subject 47/310
#
# Processing 15260: Subject 48/310
#
# Processing 15266: Subject 49/310
#
# Processing 15272: Subject 50/310
#
# Processing 15274: Subject 51/310
#
# Processing 15276: Subject 52/310
#
# Processing 15300: Subject 53/310
#
# Processing 15332: Subject 54/310
#
# Processing 15420: Subject 55/310
#
# Processing 15441: Subject 56/310
#
# Processing 15442: Subject 57/310
#
# Processing 15446: Subject 58/310
#
# Processing 15457: Subject 59/310
#
# Processing 15541: Subject 60/310
#
# Processing 15553: Subject 61/310
#
# Processing 15554: Subject 62/310
#
# Processing 15555: Subject 63/310
#
# Processing 15557: Subject 64/310
#
# Processing 15583: Subject 65/310
#
# Processing 15592: Subject 66/310
#
# Processing 15593: Subject 67/310
#
# Processing 15600: Subject 68/310
#
# Processing 15607: Subject 69/310
#
# Processing 15609: Subject 70/310
#
# Processing 15621: Subject 71/310
#
# Processing 15635: Subject 72/310
#
# Processing 15636: Subject 73/310
#
# Processing 15639: Subject 74/310
#
# Processing 15659: Subject 75/310
#
# Processing 15683: Subject 76/310
#
# Processing 15694: Subject 77/310
#
# Processing 15696: Subject 78/310
#
# Processing 15709: Subject 79/310
#
# Processing 15710: Subject 80/310
#
# Processing 15713: Subject 81/310
#
# Processing 15714: Subject 82/310
#
# Processing 15724: Subject 83/310
#
# Processing 15731: Subject 84/310
#
# Processing 15741: Subject 85/310
#
# Processing 15783: Subject 86/310
#
# Processing 15784: Subject 87/310
#
# Processing 15791: Subject 88/310
#
# Processing 15792: Subject 89/310
#
# Processing 15797: Subject 90/310
#
# Processing 15798: Subject 91/310
#
# Processing 15800: Subject 92/310
#
# Processing 15801: Subject 93/310
#
# Processing 15804: Subject 94/310
#
# Processing 15805: Subject 95/310
#
# Processing 15809: Subject 96/310
#
# Processing 15849: Subject 97/310
#
# Processing 15850: Subject 98/310
#
# Processing 15855: Subject 99/310
#
# Processing 15856: Subject 100/310
#
# Processing 15861: Subject 101/310
#
# Processing 15869: Subject 102/310
#
# Processing 15914: Subject 103/310
#
# Processing 15958: Subject 104/310
#
# Processing 15966: Subject 105/310
#
# Processing 16018: Subject 106/310
#
# Processing 16072: Subject 107/310
#
# Processing 16084: Subject 108/310
#
# Processing 16088: Subject 109/310
#
# Processing 16098: Subject 110/310
#
# Processing 16109: Subject 111/310
#
# Processing 16131: Subject 112/310
#
# Processing 16146: Subject 113/310
#
# Processing 16149: Subject 114/310
#
# Processing 16160: Subject 115/310
#
# Processing 16161: Subject 116/310
#
# Processing 16206: Subject 117/310
#
# Processing 16219: Subject 118/310
#
# Processing 16227: Subject 119/310
#
# Processing 16233: Subject 120/310
#
# Processing 16236: Subject 121/310
#
# Processing 16272: Subject 122/310
#
# Processing 16276: Subject 123/310
#
# Processing 16278: Subject 124/310
#
# Processing 16312: Subject 125/310
#
# Processing 16318: Subject 126/310
#
# Processing 16320: Subject 127/310
#
# Processing 16323: Subject 128/310
#
# Processing 16324: Subject 129/310
#
# Processing 16325: Subject 130/310
#
# Processing 16326: Subject 131/310
#
# Processing 16337: Subject 132/310
#
# Processing 16339: Subject 133/310
#
# Processing 16342: Subject 134/310
#
# Processing 16343: Subject 135/310
#
# Processing 16349: Subject 136/310
#
# Processing 16350: Subject 137/310
#
# Processing 16356: Subject 138/310
#
# Processing 16360: Subject 139/310
#
# Processing 16364: Subject 140/310
#
# Processing 16365: Subject 141/310
#
# Processing 16366: Subject 142/310
#
# Processing 16367: Subject 143/310
#
# Processing 16368: Subject 144/310
#
# Processing 16369: Subject 145/310
#
# Processing 16388: Subject 146/310
#
# Processing 16391: Subject 147/310
#
# Processing 16392: Subject 148/310
#
# Processing 16393: Subject 149/310
#
# Processing 16394: Subject 150/310
#
# Processing 16395: Subject 151/310
#
# Processing 16396: Subject 152/310
#
# Processing 16397: Subject 153/310
#
# Processing 16398: Subject 154/310
#
# Processing 16399: Subject 155/310
#
# Processing 16409: Subject 156/310
#
# Processing 16410: Subject 157/310
#
# Processing 16414: Subject 158/310
#
# Processing 16428: Subject 159/310
#
# Processing 16429: Subject 160/310
#
# Processing 16446: Subject 161/310
#
# Processing 16453: Subject 162/310
#
# Processing 16513: Subject 163/310
#
# Processing 16514: Subject 164/310
#
# Processing 16522: Subject 165/310
#
# Processing 16534: Subject 166/310
#
# Processing 16536: Subject 167/310
#
# Processing 16537: Subject 168/310
#
# Processing 16545: Subject 169/310
#
# Processing 16547: Subject 170/310
#
# Processing 16548: Subject 171/310
#
# Processing 16549: Subject 172/310
#
# Processing 16551: Subject 173/310
#
# Processing 16552: Subject 174/310
#
# Processing 16572: Subject 175/310
#
# Processing 16573: Subject 176/310
#
# Processing 16575: Subject 177/310
#
# Processing 16578: Subject 178/310
#
# Processing 16587: Subject 179/310
#
# Processing 16600: Subject 180/310
#
# Processing 16617: Subject 181/310
#
# Processing 16636: Subject 182/310
#
# Processing 16637: Subject 183/310
#
# Processing 16638: Subject 184/310
#
# Processing 16639: Subject 185/310
#
# Processing 16654: Subject 186/310
#
# Processing 16655: Subject 187/310
#
# Processing 16658: Subject 188/310
#
# Processing 16662: Subject 189/310
#
# Processing 16666: Subject 190/310
#
# Processing 16667: Subject 191/310
#
# Processing 16681: Subject 192/310
#
# Processing 16686: Subject 193/310
#
# Processing 16689: Subject 194/310
#
# Processing 16690: Subject 195/310
#
# Processing 16691: Subject 196/310
#
# Processing 16716: Subject 197/310
#
# Processing 16722: Subject 198/310
#
# Processing 16724: Subject 199/310
#
# Processing 16727: Subject 200/310
#
# Processing 16728: Subject 201/310
#
# Processing 16732: Subject 202/310
#
# Processing 16737: Subject 203/310
#
# Processing 16745: Subject 204/310
#
# Processing 16750: Subject 205/310
#
# Processing 16761: Subject 206/310
#
# Processing 16790: Subject 207/310
#
# Processing 16841: Subject 208/310
#
# Processing 16842: Subject 209/310
#
# Processing 16869: Subject 210/310
#
# Processing 16874: Subject 211/310
#
# Processing 16878: Subject 212/310
#
# Processing 16881: Subject 213/310
#
# Processing 16908: Subject 214/310
#
# Processing 16915: Subject 215/310
#
# Processing 16935: Subject 216/310
#
# Processing 17063: Subject 217/310
#
# Processing 17193: Subject 218/310
#
# Processing 17267: Subject 219/310
#
# Processing 1761: Subject 220/310
#
# Processing 1765: Subject 221/310
#
# Processing 2858: Subject 222/310
#
# Processing 2874: Subject 223/310
#
# Processing 2944: Subject 224/310
#
# Processing 3057: Subject 225/310
#
# Processing 3069: Subject 226/310
#
# Processing 3116: Subject 227/310
#
# Processing 3319: Subject 228/310
#
# Processing 3464: Subject 229/310
#
# Processing 3535: Subject 230/310
#
# Processing 3536: Subject 231/310
#
# Processing 3974: Subject 232/310
#
# Processing 3978: Subject 233/310
#
# Processing 4122: Subject 234/310
#
# Processing 4214: Subject 235/310
#
# Processing 4230: Subject 236/310
#
# Processing 4252: Subject 237/310
#
# Processing 4334: Subject 238/310
#
# Processing 4355: Subject 239/310
#
# Processing 4358: Subject 240/310
#
# Processing 4364: Subject 241/310
#
# Processing 4429: Subject 242/310
#
# Processing 4442: Subject 243/310
#
# Processing 4507: Subject 244/310
#
# Processing 4576: Subject 245/310
#
# Processing 4734: Subject 246/310
#
# Processing 4779: Subject 247/310
#
# Processing 5209: Subject 248/310
#
# Processing 5212: Subject 249/310
#
# Processing 5328: Subject 250/310
#
# Processing 5363: Subject 251/310
#
# Processing 5457: Subject 252/310
#
# Processing 5660: Subject 253/310
#
# Processing 5690: Subject 254/310
#
# Processing 5736: Subject 255/310
#
# Processing 5746: Subject 256/310
#
# Processing 5767: Subject 257/310
#
# Processing 5817: Subject 258/310
#
# Processing 5982: Subject 259/310
#
# Processing 6016: Subject 260/310
#
# Processing 6034: Subject 261/310
#
# Processing 6081: Subject 262/310
#
# Processing 6111: Subject 263/310
#
# Processing 6116: Subject 264/310
#
# Processing 6147: Subject 265/310
#
# Processing 6148: Subject 266/310
#
# Processing 6183: Subject 267/310
#
# Processing 6193: Subject 268/310
#
# Processing 6221: Subject 269/310
#
# Processing 6226: Subject 270/310
#
# Processing 6228: Subject 271/310
#
# Processing 6257: Subject 272/310
#
# Processing 6323: Subject 273/310
#
# Processing 6340: Subject 274/310
#
# Processing 6343: Subject 275/310
#
# Processing 6344: Subject 276/310
#
# Processing 6399: Subject 277/310
#
# Processing 6400: Subject 278/310
#
# Processing 6401: Subject 279/310
#
# Processing 6402: Subject 280/310
#
# Processing 6403: Subject 281/310
#
# Processing 6404: Subject 282/310
#
# Processing 6406: Subject 283/310
#
# Processing 6545: Subject 284/310
#
# Processing 6818: Subject 285/310
#
# Processing 6830: Subject 286/310
#
# Processing 6874: Subject 287/310
#
# Processing 6895: Subject 288/310
#
# Processing 6903: Subject 289/310
#
# Processing 6904: Subject 290/310
#
# Processing 6905: Subject 291/310
#
# Processing 6906: Subject 292/310
#
# Processing 6914: Subject 293/310
#
# Processing 6968: Subject 294/310
#
# Processing 7011: Subject 295/310
#
# Processing 784: Subject 296/310
#
# Processing 8037: Subject 297/310
#
# Processing 8061: Subject 298/310
#
# Processing 8079: Subject 299/310
#
# Processing 8083: Subject 300/310
#
# Processing 9009: Subject 301/310
#
# Processing 9037: Subject 302/310
#
# Processing 9069: Subject 303/310
#
# Processing 9071: Subject 304/310
#
# Processing 9114: Subject 305/310
#
# Processing 9314: Subject 306/310
#
# Processing 983: Subject 307/310
#
# Processing 15810: Subject 308/310

# %% [markdown]
# The following cell will apply intensity normalization using the Pons as a Reference region. Two images will be created, wpet_normpons.hdr and swpet_normpons.hdr (smoothed to smoothing_fwhm)

# %%
# Normalization using a pons reference region
list_dirs = os.listdir(dir_patients)

reference_region = join(anapyze_rsc, 'reference_regions', 'Pons_MNI_Ewers_1.5mm.nii.gz')
ref_data = nib.load(reference_region).get_fdata()
pons_vox = np.where(ref_data == np.unique(ref_data)[1])

for i in list_dirs:

    dir_subj = join(dir_patients, i)
    
    if isdir(dir_subj):
    
        print('\nProcessing %s: Subject %s/%s' % (i, list_dirs.index(i), len(list_dirs)))
    
        list_subj = os.listdir(dir_subj)
    
        fdg_list = []
    
        for j in list_subj:
            if j.startswith('fdg_'):
                fdg_list.append(j)
    
        for k in fdg_list:
            pet_in = join(dir_subj, k, 'swpet.hdr')

            if exists(pet_in):
                img_ = nib.load(pet_in)
                data_ = img_.get_fdata()
        
                ref_val = np.nanmean(data_[pons_vox])
                norm_data = data_ / ref_val
        
                norm_data = np.nan_to_num(norm_data, nan=0)
                norm_data[norm_data < 0] = 0
        
                pet_out = join(dir_subj, k, 'swpet_pons_norm.hdr')
                out_img = nib.Nifti1Image(norm_data, img_.affine, img_.header)
                nib.save(out_img, pet_out)
# Out:
# Processing 11409: Subject 0/310
#
# Processing 1080: Subject 1/310
#
# Processing 11443: Subject 2/310
#
# Processing 11446: Subject 3/310
#
# Processing 11453: Subject 4/310
#
# Processing 11460: Subject 5/310
#
# Processing 11477: Subject 6/310
#
# Processing 11495: Subject 7/310
#
# Processing 11614: Subject 8/310
#
# Processing 11627: Subject 9/310
#
# Processing 11731: Subject 10/310
#
# Processing 11732: Subject 11/310
#
# Processing 11766: Subject 12/310
#
# Processing 11778: Subject 13/310
#
# Processing 11782: Subject 14/310
#
# Processing 11797: Subject 15/310
#
# Processing 11841: Subject 16/310
#
# Processing 11862: Subject 17/310
#
# Processing 11879: Subject 18/310
#
# Processing 11904: Subject 19/310
#
# Processing 11913: Subject 20/310
#
# Processing 11950: Subject 21/310
#
# Processing 11962: Subject 22/310
#
# Processing 11974: Subject 23/310
#
# Processing 12011: Subject 24/310
#
# Processing 13033: Subject 25/310
#
# Processing 13043: Subject 26/310
#
# Processing 13050: Subject 27/310
#
# Processing 13059: Subject 28/310
#
# Processing 13067: Subject 29/310
#
# Processing 1307: Subject 30/310
#
# Processing 13076: Subject 31/310
#
# Processing 13091: Subject 32/310
#
# Processing 1389: Subject 33/310
#
# Processing 14091: Subject 34/310
#
# Processing 14093: Subject 35/310
#
# Processing 14120: Subject 36/310
#
# Processing 14121: Subject 37/310
#
# Processing 14122: Subject 38/310
#
# Processing 14123: Subject 39/310
#
# Processing 1436: Subject 40/310
#
# Processing 1494: Subject 41/310
#
# Processing 15156: Subject 42/310
#
# Processing 15159: Subject 43/310
#
# Processing 15184: Subject 44/310
#
# Processing 15219: Subject 45/310
#
# Processing 15220: Subject 46/310
#
# Processing 15258: Subject 47/310
#
# Processing 15260: Subject 48/310
#
# Processing 15266: Subject 49/310
#
# Processing 15272: Subject 50/310
#
# Processing 15274: Subject 51/310
#
# Processing 15276: Subject 52/310
#
# Processing 15300: Subject 53/310
#
# Processing 15332: Subject 54/310
#
# Processing 15420: Subject 55/310
#
# Processing 15441: Subject 56/310
#
# Processing 15442: Subject 57/310
#
# Processing 15446: Subject 58/310
#
# Processing 15457: Subject 59/310
#
# Processing 15541: Subject 60/310
#
# Processing 15553: Subject 61/310
#
# Processing 15554: Subject 62/310
#
# Processing 15555: Subject 63/310
#
# Processing 15557: Subject 64/310
#
# Processing 15583: Subject 65/310
#
# Processing 15592: Subject 66/310
#
# Processing 15593: Subject 67/310
#
# Processing 15600: Subject 68/310
#
# Processing 15607: Subject 69/310
#
# Processing 15609: Subject 70/310
#
# Processing 15621: Subject 71/310
#
# Processing 15635: Subject 72/310
#
# Processing 15636: Subject 73/310
#
# Processing 15639: Subject 74/310
#
# Processing 15659: Subject 75/310
#
# Processing 15683: Subject 76/310
#
# Processing 15694: Subject 77/310
#
# Processing 15696: Subject 78/310
#
# Processing 15709: Subject 79/310
#
# Processing 15710: Subject 80/310
#
# Processing 15713: Subject 81/310
#
# Processing 15714: Subject 82/310
#
# Processing 15724: Subject 83/310
#
# Processing 15731: Subject 84/310
#
# Processing 15741: Subject 85/310
#
# Processing 15783: Subject 86/310
#
# Processing 15784: Subject 87/310
#
# Processing 15791: Subject 88/310
#
# Processing 15792: Subject 89/310
#
# Processing 15797: Subject 90/310
#
# Processing 15798: Subject 91/310
#
# Processing 15800: Subject 92/310
#
# Processing 15801: Subject 93/310
#
# Processing 15804: Subject 94/310
#
# Processing 15805: Subject 95/310
#
# Processing 15809: Subject 96/310
#
# Processing 15849: Subject 97/310
#
# Processing 15850: Subject 98/310
#
# Processing 15855: Subject 99/310
#
# Processing 15856: Subject 100/310
#
# Processing 15861: Subject 101/310
#
# Processing 15869: Subject 102/310
#
# Processing 15914: Subject 103/310
#
# Processing 15958: Subject 104/310
#
# Processing 15966: Subject 105/310
#
# Processing 16018: Subject 106/310
#
# Processing 16072: Subject 107/310
#
# Processing 16084: Subject 108/310
#
# Processing 16088: Subject 109/310
#
# Processing 16098: Subject 110/310
#
# Processing 16109: Subject 111/310
#
# Processing 16131: Subject 112/310
#
# Processing 16146: Subject 113/310
#
# Processing 16149: Subject 114/310
#
# Processing 16160: Subject 115/310
#
# Processing 16161: Subject 116/310
#
# Processing 16206: Subject 117/310
#
# Processing 16219: Subject 118/310
#
# Processing 16227: Subject 119/310
#
# Processing 16233: Subject 120/310
#
# Processing 16236: Subject 121/310
#
# Processing 16272: Subject 122/310
#
# Processing 16276: Subject 123/310
#
# Processing 16278: Subject 124/310
#
# Processing 16312: Subject 125/310
#
# Processing 16318: Subject 126/310
#
# Processing 16320: Subject 127/310
#
# Processing 16323: Subject 128/310
#
# Processing 16324: Subject 129/310
#
# Processing 16325: Subject 130/310
#
# Processing 16326: Subject 131/310
#
# Processing 16337: Subject 132/310
#
# Processing 16339: Subject 133/310
#
# Processing 16342: Subject 134/310
#
# Processing 16343: Subject 135/310
#
# Processing 16349: Subject 136/310
#
# Processing 16350: Subject 137/310
#
# Processing 16356: Subject 138/310
#
# Processing 16360: Subject 139/310
#
# Processing 16364: Subject 140/310
#
# Processing 16365: Subject 141/310
#
# Processing 16366: Subject 142/310
#
# Processing 16367: Subject 143/310
#
# Processing 16368: Subject 144/310
#
# Processing 16369: Subject 145/310
#
# Processing 16388: Subject 146/310
#
# Processing 16391: Subject 147/310
#
# Processing 16392: Subject 148/310
#
# Processing 16393: Subject 149/310
#
# Processing 16394: Subject 150/310
#
# Processing 16395: Subject 151/310
#
# Processing 16396: Subject 152/310
#
# Processing 16397: Subject 153/310
#
# Processing 16398: Subject 154/310
#
# Processing 16399: Subject 155/310
#
# Processing 16409: Subject 156/310
#
# Processing 16410: Subject 157/310
#
# Processing 16414: Subject 158/310
#
# Processing 16428: Subject 159/310
#
# Processing 16429: Subject 160/310
#
# Processing 16446: Subject 161/310
#
# Processing 16453: Subject 162/310
#
# Processing 16513: Subject 163/310
#
# Processing 16514: Subject 164/310
#
# Processing 16522: Subject 165/310
#
# Processing 16534: Subject 166/310
#
# Processing 16536: Subject 167/310
#
# Processing 16537: Subject 168/310
#
# Processing 16545: Subject 169/310
#
# Processing 16547: Subject 170/310
#
# Processing 16548: Subject 171/310
#
# Processing 16549: Subject 172/310
#
# Processing 16551: Subject 173/310
#
# Processing 16552: Subject 174/310
#
# Processing 16572: Subject 175/310
#
# Processing 16573: Subject 176/310
#
# Processing 16575: Subject 177/310
#
# Processing 16578: Subject 178/310
#
# Processing 16587: Subject 179/310
#
# Processing 16600: Subject 180/310
#
# Processing 16617: Subject 181/310
#
# Processing 16636: Subject 182/310
#
# Processing 16637: Subject 183/310
#
# Processing 16638: Subject 184/310
#
# Processing 16639: Subject 185/310
#
# Processing 16654: Subject 186/310
#
# Processing 16655: Subject 187/310
#
# Processing 16658: Subject 188/310
#
# Processing 16662: Subject 189/310
#
# Processing 16666: Subject 190/310
#
# Processing 16667: Subject 191/310
#
# Processing 16681: Subject 192/310
#
# Processing 16686: Subject 193/310
#
# Processing 16689: Subject 194/310
#
# Processing 16690: Subject 195/310
#
# Processing 16691: Subject 196/310
#
# Processing 16716: Subject 197/310
#
# Processing 16722: Subject 198/310
#
# Processing 16724: Subject 199/310
#
# Processing 16727: Subject 200/310
#
# Processing 16728: Subject 201/310
#
# Processing 16732: Subject 202/310
#
# Processing 16737: Subject 203/310
#
# Processing 16745: Subject 204/310
#
# Processing 16750: Subject 205/310
#
# Processing 16761: Subject 206/310
#
# Processing 16790: Subject 207/310
#
# Processing 16841: Subject 208/310
#
# Processing 16842: Subject 209/310
#
# Processing 16869: Subject 210/310
#
# Processing 16874: Subject 211/310
#
# Processing 16878: Subject 212/310
#
# Processing 16881: Subject 213/310
#
# Processing 16908: Subject 214/310
#
# Processing 16915: Subject 215/310
#
# Processing 16935: Subject 216/310
#
# Processing 17063: Subject 217/310
#
# Processing 17193: Subject 218/310
#
# Processing 17267: Subject 219/310
#
# Processing 1761: Subject 220/310
#
# Processing 1765: Subject 221/310
#
# Processing 2858: Subject 222/310
#
# Processing 2874: Subject 223/310
#
# Processing 2944: Subject 224/310
#
# Processing 3057: Subject 225/310
#
# Processing 3069: Subject 226/310
#
# Processing 3116: Subject 227/310
#
# Processing 3319: Subject 228/310
#
# Processing 3464: Subject 229/310
#
# Processing 3535: Subject 230/310
#
# Processing 3536: Subject 231/310
#
# Processing 3974: Subject 232/310
#
# Processing 3978: Subject 233/310
#
# Processing 4122: Subject 234/310
#
# Processing 4214: Subject 235/310
#
# Processing 4230: Subject 236/310
#
# Processing 4252: Subject 237/310
#
# Processing 4334: Subject 238/310
#
# Processing 4355: Subject 239/310
#
# Processing 4358: Subject 240/310
#
# Processing 4364: Subject 241/310
#
# Processing 4429: Subject 242/310
#
# Processing 4442: Subject 243/310
#
# Processing 4507: Subject 244/310
#
# Processing 4576: Subject 245/310
#
# Processing 4734: Subject 246/310
#
# Processing 4779: Subject 247/310
#
# Processing 5209: Subject 248/310
#
# Processing 5212: Subject 249/310
#
# Processing 5328: Subject 250/310
#
# Processing 5363: Subject 251/310
#
# Processing 5457: Subject 252/310
#
# Processing 5660: Subject 253/310
#
# Processing 5690: Subject 254/310
#
# Processing 5736: Subject 255/310
#
# Processing 5746: Subject 256/310
#
# Processing 5767: Subject 257/310
#
# Processing 5817: Subject 258/310
#
# Processing 5982: Subject 259/310
#
# Processing 6016: Subject 260/310
#
# Processing 6034: Subject 261/310
#
# Processing 6081: Subject 262/310
#
# Processing 6111: Subject 263/310
#
# Processing 6116: Subject 264/310
#
# Processing 6147: Subject 265/310
#
# Processing 6148: Subject 266/310
#
# Processing 6183: Subject 267/310
#
# Processing 6193: Subject 268/310
#
# Processing 6221: Subject 269/310
#
# Processing 6226: Subject 270/310
#
# Processing 6228: Subject 271/310
#
# Processing 6257: Subject 272/310
#
# Processing 6323: Subject 273/310
#
# Processing 6340: Subject 274/310
#
# Processing 6343: Subject 275/310
#
# Processing 6344: Subject 276/310
#
# Processing 6399: Subject 277/310
#
# Processing 6400: Subject 278/310
#
# Processing 6401: Subject 279/310
#
# Processing 6402: Subject 280/310
#
# Processing 6403: Subject 281/310
#
# Processing 6404: Subject 282/310
#
# Processing 6406: Subject 283/310
#
# Processing 6545: Subject 284/310
#
# Processing 6818: Subject 285/310
#
# Processing 6830: Subject 286/310
#
# Processing 6874: Subject 287/310
#
# Processing 6895: Subject 288/310
#
# Processing 6903: Subject 289/310
#
# Processing 6904: Subject 290/310
#
# Processing 6905: Subject 291/310
#
# Processing 6906: Subject 292/310
#
# Processing 6914: Subject 293/310
#
# Processing 6968: Subject 294/310
#
# Processing 7011: Subject 295/310
#
# Processing 784: Subject 296/310
#
# Processing 8037: Subject 297/310
#
# Processing 8061: Subject 298/310
#
# Processing 8079: Subject 299/310
#
# Processing 8083: Subject 300/310
#
# Processing 9009: Subject 301/310
#
# Processing 9037: Subject 302/310
#
# Processing 9069: Subject 303/310
#
# Processing 9071: Subject 304/310
#
# Processing 9114: Subject 305/310
#
# Processing 9314: Subject 306/310
#
# Processing 983: Subject 307/310
#
# Processing 15810: Subject 308/310

# %% [markdown]
# The following cell will apply intensity normalization using the histogram intensity normalization as published by Lopez-Gonzalez et al. (Neuroimage 2020).
# This will create an image swpet_normhistogram.hdr
# This method is theoretically superior to the reference region one.

# %%
# Normalization using a data-driven method
list_dirs = os.listdir(dir_patients)
smoothing_fwhm = 4

mask_path = join(anapyze_rsc, 'mask', 'gm_cat12.nii.gz')
mask_img_ = nib.load(mask_path)

if len(mask_img_.shape) == 4:
    mask_data = mask_img_.get_fdata()[:, :, :, 0]
else:
    mask_data = mask_img_.get_fdata()[:, :, :]

mask_indx = np.where(mask_data == 1)

template_img_ = nib.load(template_pet)
smoothed_template = nibproc.smooth_image(template_img_, smoothing_fwhm, out_class=nib.AnalyzeImage)
template_data = smoothed_template.get_fdata()
mean_template = np.mean(template_data[mask_indx])

for i in list_dirs:

    dir_subj = join(dir_patients, i)

    if isdir(dir_subj):

        print('\nProcessing %s: Subject %s/%s' % (i, list_dirs.index(i), len(list_dirs)))

        list_subj = os.listdir(dir_subj)

        fdg_list = []

        for j in list_subj:
            if j.startswith('fdg_'):
                fdg_list.append(j)

        for k in fdg_list:
            pet_in = join(dir_subj, k, 'swpet.hdr')

            if exists(pet_in):
                img_ = nib.load(pet_in)
                data_ = img_.get_fdata()
        
                mean_fdg = np.mean(data_[mask_indx])
                fdg_data = data_ * (mean_template / mean_fdg)
        
                division = template_data[mask_indx] / fdg_data[mask_indx]
                values, bins = np.histogram(division, 200, range=[0.5, 2])
                amax = np.amax(values)
                indx = np.where(values == amax)
                norm_value = bins[indx][0]
                fdg_data = fdg_data * norm_value
        
                fdg_data = np.nan_to_num(fdg_data, nan=0)
                fdg_data[fdg_data < 0] = 0
        
                pet_out = join(dir_subj, k, 'swpet_hist_norm.hdr')
        
                img = nib.Nifti1Image(fdg_data, img_.affine, img_.header)
                nib.save(img, pet_out)
# Out:
# Processing 11409: Subject 0/310
#
# Processing 1080: Subject 1/310
#
# Processing 11443: Subject 2/310
#
# Processing 11446: Subject 3/310
#
# Processing 11453: Subject 4/310
#
# Processing 11460: Subject 5/310
#
# Processing 11477: Subject 6/310
#
# Processing 11495: Subject 7/310
#
# Processing 11614: Subject 8/310
#
# Processing 11627: Subject 9/310
#
# Processing 11731: Subject 10/310
#
# Processing 11732: Subject 11/310
#
# Processing 11766: Subject 12/310
#
# Processing 11778: Subject 13/310
#
# Processing 11782: Subject 14/310
#
# Processing 11797: Subject 15/310
#
# Processing 11841: Subject 16/310
#
# Processing 11862: Subject 17/310
#
# Processing 11879: Subject 18/310
#
# Processing 11904: Subject 19/310
#
# Processing 11913: Subject 20/310
#
# Processing 11950: Subject 21/310
#
# Processing 11962: Subject 22/310
#
# Processing 11974: Subject 23/310
#
# Processing 12011: Subject 24/310
#
# Processing 13033: Subject 25/310
#
# Processing 13043: Subject 26/310
#
# Processing 13050: Subject 27/310
#
# Processing 13059: Subject 28/310
#
# Processing 13067: Subject 29/310
#
# Processing 1307: Subject 30/310
#
# Processing 13076: Subject 31/310
#
# Processing 13091: Subject 32/310
#
# Processing 1389: Subject 33/310
#
# Processing 14091: Subject 34/310
#
# Processing 14093: Subject 35/310
#
# Processing 14120: Subject 36/310
#
# Processing 14121: Subject 37/310
#
# Processing 14122: Subject 38/310
#
# Processing 14123: Subject 39/310
#
# Processing 1436: Subject 40/310
#
# Processing 1494: Subject 41/310
#
# Processing 15156: Subject 42/310
#
# Processing 15159: Subject 43/310
#
# Processing 15184: Subject 44/310
#
# Processing 15219: Subject 45/310
#
# Processing 15220: Subject 46/310
#
# Processing 15258: Subject 47/310
#
# Processing 15260: Subject 48/310
#
# Processing 15266: Subject 49/310
#
# Processing 15272: Subject 50/310
#
# Processing 15274: Subject 51/310
#
# Processing 15276: Subject 52/310
#
# Processing 15300: Subject 53/310
#
# Processing 15332: Subject 54/310
#
# Processing 15420: Subject 55/310
#
# Processing 15441: Subject 56/310
#
# Processing 15442: Subject 57/310
#
# Processing 15446: Subject 58/310
#
# Processing 15457: Subject 59/310
#
# Processing 15541: Subject 60/310
#
# Processing 15553: Subject 61/310
#
# Processing 15554: Subject 62/310
#
# Processing 15555: Subject 63/310
#
# Processing 15557: Subject 64/310
#
# Processing 15583: Subject 65/310
#
# Processing 15592: Subject 66/310
#
# Processing 15593: Subject 67/310
#
# Processing 15600: Subject 68/310
#
# Processing 15607: Subject 69/310
#
# Processing 15609: Subject 70/310
#
# Processing 15621: Subject 71/310
#
# Processing 15635: Subject 72/310
#
# Processing 15636: Subject 73/310
#
# Processing 15639: Subject 74/310
#
# Processing 15659: Subject 75/310
#
# Processing 15683: Subject 76/310
#
# Processing 15694: Subject 77/310
#
# Processing 15696: Subject 78/310
#
# Processing 15709: Subject 79/310
#
# Processing 15710: Subject 80/310
#
# Processing 15713: Subject 81/310
#
# Processing 15714: Subject 82/310
#
# Processing 15724: Subject 83/310
#
# Processing 15731: Subject 84/310
#
# Processing 15741: Subject 85/310
#
# Processing 15783: Subject 86/310
#
# Processing 15784: Subject 87/310
#
# Processing 15791: Subject 88/310
#
# Processing 15792: Subject 89/310
#
# Processing 15797: Subject 90/310
#
# Processing 15798: Subject 91/310
#
# Processing 15800: Subject 92/310
#
# Processing 15801: Subject 93/310
#
# Processing 15804: Subject 94/310
#
# Processing 15805: Subject 95/310
#
# Processing 15809: Subject 96/310
#
# Processing 15849: Subject 97/310
#
# Processing 15850: Subject 98/310
#
# Processing 15855: Subject 99/310
#
# Processing 15856: Subject 100/310
#
# Processing 15861: Subject 101/310
#
# Processing 15869: Subject 102/310
#
# Processing 15914: Subject 103/310
#
# Processing 15958: Subject 104/310
#
# Processing 15966: Subject 105/310
#
# Processing 16018: Subject 106/310
#
# Processing 16072: Subject 107/310
#
# Processing 16084: Subject 108/310
#
# Processing 16088: Subject 109/310
#
# Processing 16098: Subject 110/310
#
# Processing 16109: Subject 111/310
#
# Processing 16131: Subject 112/310
#
# Processing 16146: Subject 113/310
#
# Processing 16149: Subject 114/310
#
# Processing 16160: Subject 115/310
#
# Processing 16161: Subject 116/310
#
# Processing 16206: Subject 117/310
#
# Processing 16219: Subject 118/310
#
# Processing 16227: Subject 119/310
#
# Processing 16233: Subject 120/310
#
# Processing 16236: Subject 121/310
#
# Processing 16272: Subject 122/310
#
# Processing 16276: Subject 123/310
#
# Processing 16278: Subject 124/310
#
# Processing 16312: Subject 125/310
#
# Processing 16318: Subject 126/310
#
# Processing 16320: Subject 127/310
#
# Processing 16323: Subject 128/310
#
# Processing 16324: Subject 129/310
#
# Processing 16325: Subject 130/310
#
# Processing 16326: Subject 131/310
#
# Processing 16337: Subject 132/310
#
# Processing 16339: Subject 133/310
#
# Processing 16342: Subject 134/310
#
# Processing 16343: Subject 135/310
#
# Processing 16349: Subject 136/310
#
# Processing 16350: Subject 137/310
#
# Processing 16356: Subject 138/310
#
# Processing 16360: Subject 139/310
#
# Processing 16364: Subject 140/310
#
# Processing 16365: Subject 141/310
#
# Processing 16366: Subject 142/310
#
# Processing 16367: Subject 143/310
#
# Processing 16368: Subject 144/310
#
# Processing 16369: Subject 145/310
#
# Processing 16388: Subject 146/310
#
# Processing 16391: Subject 147/310
#
# Processing 16392: Subject 148/310
#
# Processing 16393: Subject 149/310
#
# Processing 16394: Subject 150/310
#
# Processing 16395: Subject 151/310
#
# Processing 16396: Subject 152/310
#
# Processing 16397: Subject 153/310
#
# Processing 16398: Subject 154/310
#
# Processing 16399: Subject 155/310
#
# Processing 16409: Subject 156/310
#
# Processing 16410: Subject 157/310
#
# Processing 16414: Subject 158/310
#
# Processing 16428: Subject 159/310
#
# Processing 16429: Subject 160/310
#
# Processing 16446: Subject 161/310
#
# Processing 16453: Subject 162/310
#
# Processing 16513: Subject 163/310
#
# Processing 16514: Subject 164/310
#
# Processing 16522: Subject 165/310
#
# Processing 16534: Subject 166/310
#
# Processing 16536: Subject 167/310
#
# Processing 16537: Subject 168/310
#
# Processing 16545: Subject 169/310
#
# Processing 16547: Subject 170/310
#
# Processing 16548: Subject 171/310
#
# Processing 16549: Subject 172/310
#
# Processing 16551: Subject 173/310
#
# Processing 16552: Subject 174/310
#
# Processing 16572: Subject 175/310
#
# Processing 16573: Subject 176/310
#
# Processing 16575: Subject 177/310
#
# Processing 16578: Subject 178/310
#
# Processing 16587: Subject 179/310
#
# Processing 16600: Subject 180/310
#
# Processing 16617: Subject 181/310
#
# Processing 16636: Subject 182/310
#
# Processing 16637: Subject 183/310
#
# Processing 16638: Subject 184/310
#
# Processing 16639: Subject 185/310
#
# Processing 16654: Subject 186/310
#
# Processing 16655: Subject 187/310
#
# Processing 16658: Subject 188/310
#
# Processing 16662: Subject 189/310
#
# Processing 16666: Subject 190/310
#
# Processing 16667: Subject 191/310
#
# Processing 16681: Subject 192/310
#
# Processing 16686: Subject 193/310
#
# Processing 16689: Subject 194/310
#
# Processing 16690: Subject 195/310
#
# Processing 16691: Subject 196/310
#
# Processing 16716: Subject 197/310
#
# Processing 16722: Subject 198/310
#
# Processing 16724: Subject 199/310
#
# Processing 16727: Subject 200/310
#
# Processing 16728: Subject 201/310
#
# Processing 16732: Subject 202/310
#
# Processing 16737: Subject 203/310
#
# Processing 16745: Subject 204/310
#
# Processing 16750: Subject 205/310
#
# Processing 16761: Subject 206/310
#
# Processing 16790: Subject 207/310
#
# Processing 16841: Subject 208/310
#
# Processing 16842: Subject 209/310
#
# Processing 16869: Subject 210/310
#
# Processing 16874: Subject 211/310
#
# Processing 16878: Subject 212/310
#
# Processing 16881: Subject 213/310
#
# Processing 16908: Subject 214/310
#
# Processing 16915: Subject 215/310
#
# Processing 16935: Subject 216/310
#
# Processing 17063: Subject 217/310
#
# Processing 17193: Subject 218/310
#
# Processing 17267: Subject 219/310
#
# Processing 1761: Subject 220/310
#
# Processing 1765: Subject 221/310
#
# Processing 2858: Subject 222/310
#
# Processing 2874: Subject 223/310
#
# Processing 2944: Subject 224/310
#
# Processing 3057: Subject 225/310
#
# Processing 3069: Subject 226/310
#
# Processing 3116: Subject 227/310
#
# Processing 3319: Subject 228/310
#
# Processing 3464: Subject 229/310
#
# Processing 3535: Subject 230/310
#
# Processing 3536: Subject 231/310
#
# Processing 3974: Subject 232/310
#
# Processing 3978: Subject 233/310
#
# Processing 4122: Subject 234/310
#
# Processing 4214: Subject 235/310
#
# Processing 4230: Subject 236/310
#
# Processing 4252: Subject 237/310
#
# Processing 4334: Subject 238/310
#
# Processing 4355: Subject 239/310
#
# Processing 4358: Subject 240/310
#
# Processing 4364: Subject 241/310
#
# Processing 4429: Subject 242/310
#
# Processing 4442: Subject 243/310
#
# Processing 4507: Subject 244/310
#
# Processing 4576: Subject 245/310
#
# Processing 4734: Subject 246/310
#
# Processing 4779: Subject 247/310
#
# Processing 5209: Subject 248/310
#
# Processing 5212: Subject 249/310
#
# Processing 5328: Subject 250/310
#
# Processing 5363: Subject 251/310
#
# Processing 5457: Subject 252/310
#
# Processing 5660: Subject 253/310
#
# Processing 5690: Subject 254/310
#
# Processing 5736: Subject 255/310
#
# Processing 5746: Subject 256/310
#
# Processing 5767: Subject 257/310
#
# Processing 5817: Subject 258/310
#
# Processing 5982: Subject 259/310
#
# Processing 6016: Subject 260/310
#
# Processing 6034: Subject 261/310
#
# Processing 6081: Subject 262/310
#
# Processing 6111: Subject 263/310
#
# Processing 6116: Subject 264/310
#
# Processing 6147: Subject 265/310
#
# Processing 6148: Subject 266/310
#
# Processing 6183: Subject 267/310
#
# Processing 6193: Subject 268/310
#
# Processing 6221: Subject 269/310
#
# Processing 6226: Subject 270/310
#
# Processing 6228: Subject 271/310
#
# Processing 6257: Subject 272/310
#
# Processing 6323: Subject 273/310
#
# Processing 6340: Subject 274/310
#
# Processing 6343: Subject 275/310
#
# Processing 6344: Subject 276/310
#
# Processing 6399: Subject 277/310
#
# Processing 6400: Subject 278/310
#
# Processing 6401: Subject 279/310
#
# Processing 6402: Subject 280/310
#
# Processing 6403: Subject 281/310
#
# Processing 6404: Subject 282/310
#
# Processing 6406: Subject 283/310
#
# Processing 6545: Subject 284/310
#
# Processing 6818: Subject 285/310
#
# Processing 6830: Subject 286/310
#
# Processing 6874: Subject 287/310
#
# Processing 6895: Subject 288/310
#
# Processing 6903: Subject 289/310
#
# Processing 6904: Subject 290/310
#
# Processing 6905: Subject 291/310
#
# Processing 6906: Subject 292/310
#
# Processing 6914: Subject 293/310
#
# Processing 6968: Subject 294/310
#
# Processing 7011: Subject 295/310
#
# Processing 784: Subject 296/310
#
# Processing 8037: Subject 297/310
#
# Processing 8061: Subject 298/310
#
# Processing 8079: Subject 299/310
#
# Processing 8083: Subject 300/310
#
# Processing 9009: Subject 301/310
#
# Processing 9037: Subject 302/310
#
# Processing 9069: Subject 303/310
#
# Processing 9071: Subject 304/310
#
# Processing 9114: Subject 305/310
#
# Processing 9314: Subject 306/310
#
# Processing 983: Subject 307/310
#
# Processing 15810: Subject 308/310

# %%
pet_dir
# Out:
# '/Volumes/txusser_data/IBIS_DATA/Reorder_New/983/fdg_20230509'
